# %% [markdown]
# <a href="https://colab.research.google.com/github/Triveniinturi/Food-detection/blob/main/Copy_of_Food_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install --target="/content/drive/MyDrive/Colab Notebooks/YoloV8" ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 44.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 137.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 127.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 135.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 63.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 20.9 MB/s eta 0:00:00
# ...

# %%
# !cat "/content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/data.yaml"
# Out:
# train: /content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/train/images
# val: /content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/valid/images
# test: /content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/test/images
#
# nc: 12
# names:
#   - Apple
#   - Chapathi
#   - Chicken Gravy
#   - Fries
#   - Idli
#   - Pizza
#   - Rice
#   - Soda
#   - Tomato
#   - Vada
#   - banana
#   - burger

# %%
yaml_content = """train: /content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/train/images
valid: /content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/valid/images
test: /content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/test/images

nc: 12
names: ['Apple','Chapathi','Chicken Gravy','Fries','Idli','Pizza','Rice','Soda','Tomato','Vada','banana','burger']
"""

with open("/content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/data.yaml", "w") as f:
    f.write(yaml_content)

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/train/images" | head
# Out:
# 10_jpeg.rf.85d7e2f508cda35234bc8a0a1db353ac.jpg
# 10_jpeg.rf.d99c791f96d3f8ecc8abc0f3b9fd0526.jpg
# 10_jpg.rf.071c7353d87ba24af601d37a5c0b667c.jpg
# 10_jpg.rf.36de7305fdec4cd0aaa1cde3fe7758de.jpg
# 10_jpg.rf.abff3860131531fbfb2564a23c94753c.jpg
# 10_jpg.rf.e00cd2cdd7207eb618e7756d3750b1dc.jpg
# 11_jpeg.rf.3c871d928a8fe213b56ae1ec3a2498bd.jpg
# 11_jpg.rf.23a3fa765e6598fb9e9715c0b719eadf.jpg
# 11_jpg.rf.2fc30be1f068dc1a0c3a98fcb261c534.jpg
# 11_jpg.rf.57fda00f8f91d76e36e37d6ba1a85b2c.jpg

# %%
yaml_content = """
train: /content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/train/images
val: /content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/valid/images
test: /content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/test/images

nc: 12
names:
  - Apple
  - Chapathi
  - Chicken Gravy
  - Fries
  - Idli
  - Pizza
  - Rice
  - Soda
  - Tomato
  - Vada
  - banana
  - burger
"""

with open("/content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/data.yaml", "w") as f:
    f.write(yaml_content)

# !cat "/content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/data.yaml"
# Out:
# train: /content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/train/images
# val: /content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/valid/images
# test: /content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/test/images
#
# nc: 12
# names:
#   - Apple
#   - Chapathi
#   - Chicken Gravy
#   - Fries
#   - Idli
#   - Pizza
#   - Rice
#   - Soda
#   - Tomato
#   - Vada
#   - banana
#   - burger

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/train/images" | head
# !ls "/content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/valid/images" | head
# Out:
# 10_jpeg.rf.85d7e2f508cda35234bc8a0a1db353ac.jpg
# 10_jpeg.rf.d99c791f96d3f8ecc8abc0f3b9fd0526.jpg
# 10_jpg.rf.071c7353d87ba24af601d37a5c0b667c.jpg
# 10_jpg.rf.36de7305fdec4cd0aaa1cde3fe7758de.jpg
# 10_jpg.rf.abff3860131531fbfb2564a23c94753c.jpg
# 10_jpg.rf.e00cd2cdd7207eb618e7756d3750b1dc.jpg
# 11_jpeg.rf.3c871d928a8fe213b56ae1ec3a2498bd.jpg
# 11_jpg.rf.23a3fa765e6598fb9e9715c0b719eadf.jpg
# 11_jpg.rf.2fc30be1f068dc1a0c3a98fcb261c534.jpg
# 11_jpg.rf.57fda00f8f91d76e36e37d6ba1a85b2c.jpg
# 11_jpg.rf.66a7e93d5b72efa2e9b0b068a8584bbf.jpg
# 12_jpg.rf.984e7c982a55705f20376e47ecb7962c.jpg
# 12_jpg.rf.c68c2e0890952f821bb738e608f0168b.jpg
# 13_jpg.rf.132305e0232c8450d68e47096601470d.jpg
# 13_jpg.rf.f38e36b13a197716156d6728c72afa2a.jpg
# 14_jpg.rf.9819630047a504064895075935015b9e.jpg
# 15_jpg.rf.88a643bf9bf9ae998df71726cfa35911.jpg
# 15_jpg.rf.f65884c3eb36314101ac034cf8f224a0.jpg
# 16_jpg.rf.9ec8c00522b09d1e05748efcb54a93f1.jpg
# 18_jpg.rf.35e10d0d2bb147504dba2274beadeec8.jpg

# %%
import os
import sys
# !pip install ultralytics
os.environ["PYTHONPATH"]="/content/drive/MyDrive/Colab Notebooks/YoloV8"
from ultralytics import YOLO
model = YOLO("yolov8n.yaml")

# Use the model
results = model.train(data="/content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/data.yaml", epochs=100, pretrained=True, iou=0.5, visualize=True, patience=0)  # train the model
results = model.val()
# Out:
# ...
#   Using cached ultralytics-8.3.206-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# ...
# Using cached ultralytics-8.3.206-py3-none-any.whl (1.1 MB)
# Using cached ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.206 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import os
import sys
# !pip install ultralytics
os.environ["PYTHONPATH"]="/content/drive/MyDrive/Colab Notebooks/YoloV8"
from ultralytics import YOLO
model = YOLO("yolov8n.yaml")

# Use the model
results = model.train(data="/content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/data.yaml", epochs=50, pretrained=True, iou=0.5, visualize=True, patience=0)  # train the model
results = model.val()

# %%
import os
import sys
# !pip install ultralytics
os.environ["PYTHONPATH"]="/content/drive/MyDrive/Colab Notebooks/YoloV8"
from ultralytics import YOLO
model = YOLO("yolov8n.yaml")

# Use the model
results = model.train(data="/content/drive/MyDrive/Colab Notebooks/YoloV8/dataset/data.yaml", epochs=300, pretrained=True, iou=0.5, visualize=True, patience=0)  # train the model
results = model.val()
